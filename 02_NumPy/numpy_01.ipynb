# %%
import numpy as np
import time

# %%
#arr = np.array([1,2,3,4,5])
#print(arr, type(arr))
# Out:
# [1 2 3 4 5] <class 'numpy.ndarray'>

# %%
size = 10_000_000

py_list = list(range(size))

start = time.time()

py_square = [x**2 for x in py_list]
end = time.time()
print(f" the time taken to calculate square - {end-start}")

#numpy quare vectoriztion


py_array = np.array(py_list)
start = time.time()
sqaure_arr = py_array ** 2

end = time.time()
print(f" the time taken to calculate square - {end-start}")
# Out:
#  the time taken to calculate square - 1.2632880210876465
#  the time taken to calculate square - 0.0273740291595459
