# %%
import pandas as pd

info = {
    "Name" : ["Amit", "Tinnu", "Roan", "Mayank"],

    "Cgpa" : [9.5,8,5,6]

}

df = pd.DataFrame(info)
print(df)
# Out:
#      Name  Cgpa
# 0    Amit   9.5
# 1   Tinnu   8.0
# 2    Roan   5.0
# 3  Mayank   6.0

# %%
df
# Out:
#      Name  Cgpa
# 0    Amit   9.5
# 1   Tinnu   8.0
# 2    Roan   5.0
# 3  Mayank   6.0
