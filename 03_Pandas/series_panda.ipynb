# %%
import pandas as pd

s = pd.Series([1,2,3,4,5])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s_2 = pd.Series([23,19,20,25] , index = ["Alex","Anil","Hemant","Muskan"])
print(s_2)
print(s_2)
print(s_2.index)
# Out:
# Alex      23
# Anil      19
# Hemant    20
# Muskan    25
# dtype: int64
# Alex      23
# Anil      19
# Hemant    20
# Muskan    25
# dtype: int64
# Index(['Alex', 'Anil', 'Hemant', 'Muskan'], dtype='object')
