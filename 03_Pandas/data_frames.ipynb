# %%
import pandas as pd
info = {
    "Name":["Amit","kundun","shubham","Kholi"],
    "Age": [20,21,23,25],
    "cgpa":[8,9,6,7.5]
}

stat = pd.DataFrame(info)
print(stat)


#list

list_data = [["amit",24],["Roan",25],["lucky",19]]
li = pd.DataFrame(list_data,columns = ["Name","Age"])
print(li)
# Out:
#       Name  Age  cgpa
# 0     Amit   20   8.0
# 1   kundun   21   9.0
# 2  shubham   23   6.0
# 3    Kholi   25   7.5
#     Name  Age
# 0   amit   24
# 1   Roan   25
# 2  lucky   19

# %%
stat
# Out:
#       Name  Age  cgpa
# 0     Amit   20   8.0
# 1   kundun   21   9.0
# 2  shubham   23   6.0
# 3    Kholi   25   7.5
