# %%
import pandas as pd

info = {

    "Name":["Amit","Tinnu","Ramesh"],
    "Age": [12,13,15],
}
df = pd.DataFrame(info)
print(df)
# Out:
#      Name  Age
# 0    Amit   12
# 1   Tinnu   13
# 2  Ramesh   15

# %%
s = pd.Series([1,4,5,6,7])
print(s)
# Out:
# 0    1
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64
